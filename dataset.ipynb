# %% [markdown]
# # Dataset Compilation
#
# #### Introduction
#
# User can use this notebook to generate required embedding from a graph network,  label the positive data and obtain the final dataset(s).
#
# <u>Define positive gene:</u>
#
# Input:	Genetic association data, predefined score threshold
#
# Process:    filter out the gene IDs below the score threshold, remaining gene ID will be the positive genes to the disease
#
# Quality control:	Manually filter the data according to the threshold. It should match the number of records in the output csv
#
# Output: positive gene list, in csv format
#
# Remark:	user can modify the threshold for other needs, or use other disease association data for positive labelling
#
# <u>Learn embedding: </u>
#
# Input:	Largest subgraph of the PPI network, grid of hyperparameters for node embedding
#
# Process:	Use node2vec to learn embeddings according to the parameter grid
#
# Quality control:
# -	Number of column should match the dimension specified
# -	File names should match with the parameter specified
# -	Number of row should match the number of total nodes in of the input subgraph
#
# Output:
# -	Tubular embedding file in emb format, respective to each parameter setting
# -	Binary files of the node2vec models, in pickle format
#
# <u>Dataset compilation:</u>
#
# Input:	Positive gene list, embedding file
#
# Process:	For each embedding file, parse the embedding data, and label the gene with class label {1: positive, 0: unlabelled}
#
# Quality control:
# -	9 sets of datasets should be generated. Each with the correct number of column. All should have the same number of rows
# -	Manually check the sum of y label are match the number of positive genes
#
# Output:	For each embedding file, generate a dataset, in csv format
#
# Remarks:	user can define their own parameter grid

# %% [markdown]
# #### Import Libraries

# %%
import os
import pandas as pd
import pickle
from node2vec import Node2Vec

# %% [markdown]
# #### Define helper functions

# %%
# define helper function to parse embedding output of node2vec
def load_embedding(file_path_and_name):
    '''
    read the embedding file which is export from the node2vec. parse the embedding and output as a pandas dataframe
    parameter:
        file_path_and_name: str, the embedding file including the path
    return: 
        df: pandas dataframe object
    '''
    with open(file_path_and_name, 'r') as file:
        lines = file.readlines()

    num_rows, num_features = map(int, lines[0].split())

    data = []

    for line in lines[1:]:
        values = line.strip().split()
        data.append(values)

    df = pd.DataFrame(data)

    column_names = ['id'] + ['feature_' + str(i) for i in range(1, num_features+1)]
    df.columns = column_names

    return df

# define helper function to positive labelling data
def positive_labelling (data, positive_ids):
    '''
    label positive data should the key match with the key in the data object. 1 for positive class, 0 the otherwise
    the labelled column is 'y'
    
    parameters:
        data: pandas dataframe, the target dataset
        positive_ids: pandas dataframe, the list of positive id
    retrun
        data: pandas dataframe, a dataframe stacked with a column 'y' as the class label of the data
    '''
    data = data.copy()
    def set_y_value(row):
        if row['id'] in positive_ids:
            return 1
        else:
            return 0

    data['y'] = data.apply(set_y_value, axis=1)

    return data

# %% [markdown]
# #### Load required data files

# %%
# load the largest PPI subgraph

ppi_subgraph_path = os.path.join('data', 'ppi', 'largest_subgraph.gpickle')

with open(ppi_subgraph_path, 'rb') as f:
    largest_subgraph = pickle.load(f)

# %% [markdown]
# #### Set threshold of Disese Gene Association Score. For use of Positive Labelling

# %%
# load the disease genetic association list
dise_asso_score = pd.read_csv(os.path.join('open_targets_data', 'RAGeneticAssociationAll.csv'))

# %%
# preview the list
dise_asso_score
# Out:
#            target_id target_approved_symbol   disease_id  \
# 0    ENSG00000164512                ANKRD55  EFO_0000685
# 1    ENSG00000175354                  PTPN2  EFO_0000685
# 2    ENSG00000172575                RASGRP1  EFO_0000685
# 3    ENSG00000150347                 ARID5B  EFO_0000685
# 4    ENSG00000198369                 SPRED2  EFO_0000685
# ..               ...                    ...          ...
# 880  ENSG00000131435                 PDLIM4  EFO_0000685
# 881  ENSG00000156831                 NSMCE2  EFO_0000685
# 882  ENSG00000197162                 ZNF785  EFO_0000685
# 883  ENSG00000151135                TMEM263  EFO_0000685
# 884  ENSG00000142166                 IFNAR1  EFO_0000685
#
#              disease_name  genetic_association_score_Indirect_and_direct
# 0    rheumatoid arthritis                                       0.885188
# 1    rheumatoid arthritis                                       0.846631
# 2    rheumatoid arthritis                                       0.829440
# 3    rheumatoid arthritis                                       0.792187
# 4    rheumatoid arthritis                                       0.789214
# ..                    ...                                            ...
# 880  rheumatoid arthritis                                       0.031211
# 881  rheumatoid arthritis                                       0.031077
# 882  rheumatoid arthritis                                       0.031049
# 883  rheumatoid arthritis                                       0.030665
# 884  rheumatoid arthritis                                       0.030441
#
# [885 rows x 5 columns]

# %%
# set the Gene Association threshold, it will be use for labeling the positive lables in the dataset
SCORE_TH = 0.2

# %%
dise_asso_score_TH = dise_asso_score.loc[dise_asso_score['genetic_association_score_Indirect_and_direct'] > SCORE_TH]
dise_asso_score_TH.to_csv(os.path.join('data', 'others', 'dise_asso_score_TH.csv'))

# %%
dise_asso_score_TH
# Out:
#            target_id target_approved_symbol   disease_id  \
# 0    ENSG00000164512                ANKRD55  EFO_0000685
# 1    ENSG00000175354                  PTPN2  EFO_0000685
# 2    ENSG00000172575                RASGRP1  EFO_0000685
# 3    ENSG00000150347                 ARID5B  EFO_0000685
# 4    ENSG00000198369                 SPRED2  EFO_0000685
# ..               ...                    ...          ...
# 398  ENSG00000111785                  RIC8B  EFO_0000685
# 399  ENSG00000135116                    HRK  EFO_0000685
# 400  ENSG00000138311                 ZNF365  EFO_0000685
# 401  ENSG00000119522                DENND1A  EFO_0000685
# 402  ENSG00000065361                  ERBB3  EFO_0000685
#
#              disease_name  genetic_association_score_Indirect_and_direct
# 0    rheumatoid arthritis                                       0.885188
# 1    rheumatoid arthritis                                       0.846631
# 2    rheumatoid arthritis                                       0.829440
# 3    rheumatoid arthritis                                       0.792187
# 4    rheumatoid arthritis                                       0.789214
# ..                    ...                                            ...
# 398  rheumatoid arthritis                                       0.206936
# 399  rheumatoid arthritis                                       0.206170
# 400  rheumatoid arthritis                                       0.205471
# 401  rheumatoid arthritis                                       0.204873
# 402  rheumatoid arthritis                                       0.202890
#
# [403 rows x 5 columns]

# %% [markdown]
# #### Set File Paths for Embeddings and Datasets

# %%
temp_folder = os.path.join('tempfolder')
datasets_path = os.path.join('data', 'datasets')
embeddings_path = os.path.join('data', 'embeddings')

# %% [markdown]
# #### Learn Embeddings from Graph

# %%
# learn embedding by node2vec
# caution: each embedding will take a long time to run
# budget time: for 1 embedding model, it takes more than 320 minutes to finish initialiation and fitting
# for the params grid in the below, it will create 9 embedding models

# Define the parameter grid
params = {
    'p': [4],
    'q': [1],
    'weight_key': ['scoring'],
    'dimensions': [128,96,64],
    'walk_length': [100],
    'num_walks': [500],
    'workers': [4],
    'temp_folder': [temp_folder],
    'seed': [None, 37, 44]
}

# Dictionary to store initialized objects
node2vec_models = {}

# Iterate through parameter combinations and initialize objects
for dimension in params['dimensions']:
    for walk_length in params['walk_length']:
        for num_walks in params['num_walks']:
            for workers in params['workers']:
                for seed in params['seed']:
                    for weight_key in params['weight_key']:
                        for temp_folder in params['temp_folder']:
                            for p in params['p']:
                                for q in params['q']:
                                    if seed:
                                        key = f"p_{p}_q_{q}_dim_{dimension}_walkleng_{walk_length}_numwalks_{num_walks}_seed_{seed}"
                                    else:
                                        key = f"p_{p}_q_{q}_dim_{dimension}_walkleng_{walk_length}_numwalks_{num_walks}"

                                    node2vec_obj = Node2Vec(
                                        largest_subgraph, p=p, q=q, weight_key=weight_key,
                                        dimensions=dimension, walk_length=walk_length,
                                        num_walks=num_walks, workers=workers,
                                        temp_folder=temp_folder, seed=seed
                                    )
                                    node2vec_models[key] = node2vec_obj.fit(window=10, min_count=1, batch_words=4)
                                    
                                    # save the models into gensim embeddings format
                                    filename = key + '.emb'
                                    file_path = os.path.join(embeddings_path, filename)
                                    node2vec_models[key].wv.save_word2vec_format(file_path)
# Out:
# Computing transition probabilities:   0%|          | 0/16210 [00:00<?, ?it/s]
# Generating walks (CPU: 2):   0%|          | 0/125 [00:00<?, ?it/s]
#
#
# Generating walks (CPU: 2):   2%|▏         | 2/125 [01:23<1:26:04, 41.99s/it]
#
#
# Generating walks (CPU: 2):   2%|▏         | 3/125 [02:51<2:04:17, 61.13s/it]
#
#
# Generating walks (CPU: 2):   3%|▎         | 4/125 [04:21<2:24:39, 71.73s/it]
#
#
# Generating walks (CPU: 2):   4%|▍         | 5/125 [05:44<2:31:08, 75.57s/it]
#
#
# Generating walks (CPU: 2):   5%|▍         | 6/125 [07:09<2:36:10, 78.75s/it]
#
#
# Generating walks (CPU: 2):   6%|▌         | 7/125 [08:40<2:42:29, 82.62s/it]
#
#
# Generating walks (CPU: 2):   6%|▋         | 8/125 [10:10<2:45:38, 84.94s/it]
#
#
# Generating walks (CPU: 2):   7%|▋         | 9/125 [11:36<2:45:03, 85.38s/it]
#
#
# Generating walks (CPU: 2):   8%|▊         | 10/125 [12:57<2:41:19, 84.17s/it]
#
#
# Generating walks (CPU: 2):   9%|▉         | 11/125 [14:20<2:38:52, 83.62s/it]
#
#
# Generating walks (CPU: 2):  10%|▉         | 12/125 [15:47<2:39:43, 84.81s/it]
#
#
# Generating walks (CPU: 2):  10%|█         | 13/125 [17:16<2:40:15, 85.85s/it]
#
#
# Generating walks (CPU: 2):  11%|█         | 14/125 [18:40<2:37:55, 85.36s/it]
#
#
# Generating walks (CPU: 2):  12%|█▏        | 15/125 [19:57<2:31:53, 82.85s/it]
#
#
# Generating walks (CPU: 2):  13%|█▎        | 16/125 [21:23<2:32:15, 83.82s/it]
#
#
# Generating walks (CPU: 2):  14%|█▎        | 17/125 [22:48<2:31:30, 84.17s/it]
#
#
# Generating walks (CPU: 2):  14%|█▍        | 18/125 [24:14<2:31:19, 84.85s/it]
#
#
# Generating walks (CPU: 2):  16%|█▌        | 20/125 [27:02<2:27:13, 84.13s/it]
#
#
# Generating walks (CPU: 2):  17%|█▋        | 21/125 [28:23<2:24:21, 83.29s/it]
#
#
# Generating walks (CPU: 2):  18%|█▊        | 22/125 [29:43<2:21:14, 82.28s/it]
#
#
# Generating walks (CPU: 2):  18%|█▊        | 23/125 [31:06<2:19:59, 82.35s/it]
#
#
# Generating walks (CPU: 2):  19%|█▉        | 24/125 [32:34<2:21:41, 84.17s/it]
#
#
# Generating walks (CPU: 2):  20%|██        | 25/125 [34:09<2:25:52, 87.53s/it]
#
#
# Generating walks (CPU: 2):  21%|██        | 26/125 [35:42<2:26:48, 88.97s/it]
#
#
# Generating walks (CPU: 2):  22%|██▏       | 27/125 [37:03<2:21:39, 86.73s/it]
#
#
# Generating walks (CPU: 2):  22%|██▏       | 28/125 [38:33<2:21:26, 87.49s/it]
#
#
# Generating walks (CPU: 2):  23%|██▎       | 29/125 [39:58<2:18:53, 86.81s/it]
#
#
# Generating walks (CPU: 2):  24%|██▍       | 30/125 [41:24<2:17:05, 86.58s/it]
#
#
# Generating walks (CPU: 2):  25%|██▍       | 31/125 [42:51<2:16:03, 86.85s/it]
#
#
# Generating walks (CPU: 2):  26%|██▌       | 32/125 [44:20<2:15:19, 87.31s/it]
#
#
# Generating walks (CPU: 2):  26%|██▋       | 33/125 [45:43<2:12:06, 86.16s/it]
#
#
# Generating walks (CPU: 2):  27%|██▋       | 34/125 [47:08<2:09:54, 85.65s/it]
#
#
# Generating walks (CPU: 2):  28%|██▊       | 35/125 [48:28<2:06:08, 84.09s/it]
#
#
# Generating walks (CPU: 2):  29%|██▉       | 36/125 [49:59<2:07:42, 86.10s/it]
#
#
# Generating walks (CPU: 2):  30%|██▉       | 37/125 [51:20<2:04:04, 84.60s/it]
#
#
# Generating walks (CPU: 2):  30%|███       | 38/125 [52:40<2:00:27, 83.07s/it]
#
#
# Generating walks (CPU: 2):  31%|███       | 39/125 [54:04<1:59:36, 83.44s/it]
# Generating walks (CPU: 2):  32%|███▏      | 40/125 [55:25<1:57:24, 82.88s/it]
#
#
# Generating walks (CPU: 2):  33%|███▎      | 41/125 [56:57<1:59:40, 85.48s/it]
#
#
# Generating walks (CPU: 2):  34%|███▎      | 42/125 [58:23<1:58:40, 85.79s/it]
#
#
# Generating walks (CPU: 2):  34%|███▍      | 43/125 [59:49<1:57:03, 85.65s/it]
#
#
# Generating walks (CPU: 2):  35%|███▌      | 44/125 [1:01:11<1:54:06, 84.53s/it]
#
#
# Generating walks (CPU: 2):  36%|███▌      | 45/125 [1:02:36<1:52:52, 84.66s/it]
#
# Generating walks (CPU: 2):  37%|███▋      | 46/125 [1:03:54<1:48:59, 82.78s/it]
#
#
# Generating walks (CPU: 2):  38%|███▊      | 47/125 [1:05:16<1:47:26, 82.65s/it]
#
#
# Generating walks (CPU: 2):  38%|███▊      | 48/125 [1:06:42<1:47:09, 83.49s/it]
#
#
# Generating walks (CPU: 2):  39%|███▉      | 49/125 [1:08:02<1:44:28, 82.48s/it]
#
#
# Generating walks (CPU: 2):  40%|████      | 50/125 [1:09:28<1:44:34, 83.67s/it]
#
#
# Generating walks (CPU: 2):  41%|████      | 51/125 [1:10:55<1:44:12, 84.49s/it]
#
#
# Generating walks (CPU: 2):  42%|████▏     | 52/125 [1:12:27<1:45:26, 86.66s/it]
#
#
# Generating walks (CPU: 2):  42%|████▏     | 53/125 [1:13:54<1:44:18, 86.92s/it]
# Generating walks (CPU: 2):  43%|████▎     | 54/125 [1:15:25<1:44:16, 88.11s/it]
#
#
#
#
# Generating walks (CPU: 2):  44%|████▍     | 55/125 [1:16:55<1:43:30, 88.72s/it]
# Generating walks (CPU: 2):  45%|████▍     | 56/125 [1:18:23<1:41:42, 88.45s/it]
#
#
#
#
# Generating walks (CPU: 2):  46%|████▌     | 57/125 [1:19:55<1:41:30, 89.57s/it]
#
#
# Generating walks (CPU: 2):  46%|████▋     | 58/125 [1:21:22<1:39:06, 88.76s/it]
#
#
# Generating walks (CPU: 2):  47%|████▋     | 59/125 [1:22:51<1:37:43, 88.84s/it]
# Generating walks (CPU: 2):  48%|████▊     | 60/125 [1:24:17<1:35:10, 87.85s/it]
#
#
# Generating walks (CPU: 2):  49%|████▉     | 61/125 [1:25:43<1:33:19, 87.48s/it]
#
#
# Generating walks (CPU: 2):  50%|████▉     | 62/125 [1:27:07<1:30:51, 86.54s/it]
#
#
# Generating walks (CPU: 2):  50%|█████     | 63/125 [1:28:38<1:30:31, 87.60s/it]
#
#
# Generating walks (CPU: 2):  51%|█████     | 64/125 [1:30:10<1:30:24, 88.93s/it]
#
#
# Generating walks (CPU: 2):  52%|█████▏    | 65/125 [1:31:33<1:27:22, 87.38s/it]
#
#
# Generating walks (CPU: 2):  53%|█████▎    | 66/125 [1:33:02<1:26:23, 87.86s/it]
#
#
# Generating walks (CPU: 2):  54%|█████▎    | 67/125 [1:34:35<1:26:20, 89.32s/it]
#
#
# Generating walks (CPU: 2):  54%|█████▍    | 68/125 [1:36:07<1:25:34, 90.08s/it]
#
#
# Generating walks (CPU: 2):  55%|█████▌    | 69/125 [1:37:39<1:24:41, 90.74s/it]
#
#
# Generating walks (CPU: 2):  56%|█████▌    | 70/125 [1:39:09<1:22:55, 90.47s/it]
#
#
# Generating walks (CPU: 2):  57%|█████▋    | 71/125 [1:40:41<1:21:42, 90.79s/it]
#
#
# Generating walks (CPU: 2):  58%|█████▊    | 72/125 [1:42:06<1:18:52, 89.30s/it]
#
#
#
#
# Generating walks (CPU: 2):  58%|█████▊    | 73/125 [1:43:40<1:18:24, 90.46s/it]
#
#
# Generating walks (CPU: 2):  59%|█████▉    | 74/125 [1:45:07<1:16:07, 89.56s/it]
# Generating walks (CPU: 2):  60%|██████    | 75/125 [1:46:35<1:14:07, 88.95s/it]
#
#
# Generating walks (CPU: 2):  61%|██████    | 76/125 [1:48:03<1:12:35, 88.88s/it]
#
#
# Generating walks (CPU: 2):  62%|██████▏   | 77/125 [1:49:32<1:11:06, 88.89s/it]
#
#
# Generating walks (CPU: 2):  62%|██████▏   | 78/125 [1:50:57<1:08:36, 87.59s/it]
#
#
# Generating walks (CPU: 2):  63%|██████▎   | 79/125 [1:52:23<1:06:55, 87.30s/it]
#
#
# Generating walks (CPU: 2):  64%|██████▍   | 80/125 [1:53:47<1:04:35, 86.13s/it]
#
#
# Generating walks (CPU: 2):  65%|██████▍   | 81/125 [1:55:21<1:05:03, 88.71s/it]
#
#
# Generating walks (CPU: 2):  66%|██████▌   | 82/125 [1:56:51<1:03:43, 88.93s/it]
#
#
# Generating walks (CPU: 2):  66%|██████▋   | 83/125 [1:58:14<1:01:01, 87.18s/it]
#
#
# Generating walks (CPU: 2):  67%|██████▋   | 84/125 [1:59:44<1:00:13, 88.14s/it]
#
#
# Generating walks (CPU: 2):  68%|██████▊   | 85/125 [2:01:10<58:18, 87.47s/it]
#
#
# Generating walks (CPU: 2):  69%|██████▉   | 86/125 [2:02:35<56:13, 86.49s/it]
#
#
# Generating walks (CPU: 2):  70%|██████▉   | 87/125 [2:04:02<55:00, 86.85s/it]
#
#
# Generating walks (CPU: 2):  70%|███████   | 88/125 [2:05:33<54:15, 87.98s/it]
#
#
# Generating walks (CPU: 2):  71%|███████   | 89/125 [2:06:55<51:49, 86.37s/it]
#
#
# Generating walks (CPU: 2):  72%|███████▏  | 90/125 [2:08:15<49:11, 84.33s/it]
#
#
# Generating walks (CPU: 2):  73%|███████▎  | 91/125 [2:09:41<48:04, 84.85s/it]
#
#
# Generating walks (CPU: 2):  74%|███████▎  | 92/125 [2:11:07<46:48, 85.11s/it]
#
#
# Generating walks (CPU: 2):  74%|███████▍  | 93/125 [2:12:28<44:46, 83.97s/it]
#
#
# Generating walks (CPU: 2):  75%|███████▌  | 94/125 [2:13:49<42:54, 83.06s/it]
#
#
# Generating walks (CPU: 2):  76%|███████▌  | 95/125 [2:15:12<41:30, 83.00s/it]
# Generating walks (CPU: 2):  77%|███████▋  | 96/125 [2:16:33<39:50, 82.42s/it]
#
#
#
#
# Generating walks (CPU: 2):  78%|███████▊  | 97/125 [2:18:05<39:37, 84.92s/it]
#
# Generating walks (CPU: 2):  78%|███████▊  | 98/125 [2:19:33<38:47, 86.21s/it]
# Generating walks (CPU: 2):  79%|███████▉  | 99/125 [2:20:59<37:18, 86.11s/it]
#
#
# Generating walks (CPU: 2):  80%|████████  | 100/125 [2:22:28<36:14, 86.98s/it]
#
#
# Generating walks (CPU: 2):  81%|████████  | 101/125 [2:23:54<34:39, 86.63s/it]
#
#
# Generating walks (CPU: 2):  82%|████████▏ | 102/125 [2:25:12<32:17, 84.23s/it]
#
#
# Generating walks (CPU: 2):  82%|████████▏ | 103/125 [2:26:41<31:25, 85.69s/it]
#
#
# Generating walks (CPU: 2):  83%|████████▎ | 104/125 [2:28:06<29:51, 85.30s/it]
#
#
# Generating walks (CPU: 2):  84%|████████▍ | 105/125 [2:29:29<28:13, 84.67s/it]
#
#
# Generating walks (CPU: 2):  85%|████████▍ | 106/125 [2:30:49<26:23, 83.32s/it]
#
#
# Generating walks (CPU: 1): 100%|██████████| 125/125 [2:32:47<00:00, 73.34s/it]
#
#
#
# Generating walks (CPU: 2):  86%|████████▋ | 108/125 [2:33:27<22:40, 80.05s/it]
#
#
# Generating walks (CPU: 2):  87%|████████▋ | 109/125 [2:34:30<19:55, 74.73s/it]
#
#
# Generating walks (CPU: 2):  88%|████████▊ | 110/125 [2:35:29<17:29, 69.99s/it]
#
#
# Generating walks (CPU: 2):  89%|████████▉ | 111/125 [2:36:31<15:49, 67.83s/it]
#
#
# Generating walks (CPU: 2):  90%|████████▉ | 112/125 [2:37:30<14:05, 65.06s/it]
#
#
# Generating walks (CPU: 2):  90%|█████████ | 113/125 [2:38:29<12:37, 63.13s/it]
#
#
# Generating walks (CPU: 2):  91%|█████████ | 114/125 [2:39:30<11:26, 62.45s/it]
#
#
# Generating walks (CPU: 2):  92%|█████████▏| 115/125 [2:40:31<10:20, 62.07s/it]
#
#
# Generating walks (CPU: 2):  93%|█████████▎| 116/125 [2:41:36<09:28, 63.11s/it]
#
#
# Generating walks (CPU: 2):  94%|█████████▎| 117/125 [2:42:34<08:10, 61.37s/it]
#
# Generating walks (CPU: 2):  94%|█████████▍| 118/125 [2:43:37<07:12, 61.86s/it]
#
#
# Generating walks (CPU: 2):  95%|█████████▌| 119/125 [2:44:38<06:10, 61.73s/it]
#
#
# Generating walks (CPU: 2):  96%|█████████▌| 120/125 [2:45:38<05:05, 61.09s/it]
# Generating walks (CPU: 2):  97%|█████████▋| 121/125 [2:46:39<04:04, 61.16s/it]
#
#
# Generating walks (CPU: 2):  98%|█████████▊| 122/125 [2:47:41<03:04, 61.52s/it]
#
#
# Generating walks (CPU: 2):  98%|█████████▊| 123/125 [2:48:45<02:04, 62.11s/it]
#
#
# Generating walks (CPU: 2):  99%|█████████▉| 124/125 [2:49:46<01:01, 61.96s/it]
#
#
# Generating walks (CPU: 2): 100%|██████████| 125/125 [2:50:47<00:00, 61.43s/it]
#
#
# Generating walks (CPU: 2): 100%|██████████| 125/125 [2:51:44<00:00, 82.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating walks (CPU: 3): 100%|██████████| 125/125 [2:54:48<00:00, 83.91s/it]
# Generating walks (CPU: 4): 100%|██████████| 125/125 [2:55:07<00:00, 84.06s/it]
# Computing transition probabilities:   0%|          | 0/16210 [00:00<?, ?it/s]
# Generating walks (CPU: 1):   0%|          | 0/125 [00:00<?, ?it/s]
#
#
#
#
#
# Generating walks (CPU: 1):   2%|▏         | 2/125 [01:24<1:26:17, 42.09s/it]
#
#
# Generating walks (CPU: 1):   2%|▏         | 3/125 [02:54<2:06:08, 62.04s/it]
#
#
# Generating walks (CPU: 1):   3%|▎         | 4/125 [04:19<2:22:33, 70.69s/it]
#
#
# Generating walks (CPU: 1):   4%|▍         | 5/125 [05:42<2:30:19, 75.17s/it]
#
#
# Generating walks (CPU: 1):   5%|▍         | 6/125 [07:12<2:38:19, 79.83s/it]
#
#
# Generating walks (CPU: 1):   6%|▌         | 7/125 [08:40<2:42:13, 82.49s/it]
#
#
# Generating walks (CPU: 1):   6%|▋         | 8/125 [10:10<2:45:29, 84.87s/it]
#
#
#
#
# Generating walks (CPU: 1):   7%|▋         | 9/125 [11:40<2:47:11, 86.48s/it]
#
#
# Generating walks (CPU: 1):   8%|▊         | 10/125 [13:04<2:44:38, 85.90s/it]
#
#
# Generating walks (CPU: 1):   9%|▉         | 11/125 [14:42<2:49:54, 89.43s/it]
#
#
# Generating walks (CPU: 1):  10%|▉         | 12/125 [16:08<2:46:23, 88.35s/it]
#
#
# Generating walks (CPU: 1):  10%|█         | 13/125 [17:40<2:46:51, 89.39s/it]
#
#
# Generating walks (CPU: 1):  11%|█         | 14/125 [19:01<2:40:58, 87.02s/it]
#
#
# Generating walks (CPU: 1):  12%|█▏        | 15/125 [20:34<2:42:51, 88.83s/it]
#
#
#
# Generating walks (CPU: 1):  13%|█▎        | 16/125 [22:06<2:43:07, 89.79s/it]
#
#
#
#
# Generating walks (CPU: 1):  14%|█▎        | 17/125 [23:29<2:37:38, 87.58s/it]
#
#
# Generating walks (CPU: 1):  14%|█▍        | 18/125 [24:56<2:36:06, 87.54s/it]
#
#
# Generating walks (CPU: 1):  15%|█▌        | 19/125 [26:19<2:32:19, 86.22s/it]
#
#
# Generating walks (CPU: 1):  16%|█▌        | 20/125 [27:48<2:32:27, 87.12s/it]
#
#
# Generating walks (CPU: 1):  17%|█▋        | 21/125 [29:11<2:28:44, 85.82s/it]
#
#
# Generating walks (CPU: 1):  18%|█▊        | 22/125 [30:37<2:27:20, 85.83s/it]
#
#
# Generating walks (CPU: 1):  18%|█▊        | 23/125 [32:06<2:27:30, 86.77s/it]
#
#
# Generating walks (CPU: 1):  19%|█▉        | 24/125 [33:31<2:25:11, 86.25s/it]
#
#
# Generating walks (CPU: 1):  20%|██        | 25/125 [34:59<2:24:23, 86.64s/it]
#
#
# Generating walks (CPU: 1):  21%|██        | 26/125 [36:24<2:22:33, 86.40s/it]
#
#
#
#
# Generating walks (CPU: 1):  22%|██▏       | 27/125 [37:53<2:21:55, 86.89s/it]
#
#
# Generating walks (CPU: 1):  22%|██▏       | 28/125 [39:22<2:21:32, 87.55s/it]
#
#
# Generating walks (CPU: 1):  23%|██▎       | 29/125 [40:49<2:20:13, 87.64s/it]
#
#
# Generating walks (CPU: 1):  24%|██▍       | 30/125 [42:18<2:19:17, 87.98s/it]
#
#
#
# Generating walks (CPU: 1):  25%|██▍       | 31/125 [43:48<2:18:38, 88.49s/it]
#
#
# Generating walks (CPU: 1):  26%|██▌       | 32/125 [45:18<2:17:41, 88.84s/it]
#
#
# Generating walks (CPU: 1):  26%|██▋       | 33/125 [46:43<2:14:42, 87.86s/it]
#
#
# Generating walks (CPU: 1):  27%|██▋       | 34/125 [48:09<2:12:18, 87.24s/it]
#
#
# Generating walks (CPU: 1):  28%|██▊       | 35/125 [49:38<2:11:54, 87.94s/it]
#
#
#
#
# Generating walks (CPU: 1):  29%|██▉       | 36/125 [51:07<2:10:52, 88.23s/it]
#
#
# Generating walks (CPU: 1):  30%|██▉       | 37/125 [52:34<2:08:40, 87.74s/it]
#
#
# Generating walks (CPU: 1):  30%|███       | 38/125 [54:02<2:07:10, 87.71s/it]
#
#
# Generating walks (CPU: 1):  31%|███       | 39/125 [55:34<2:07:33, 88.99s/it]
#
#
# Generating walks (CPU: 1):  32%|███▏      | 40/125 [57:01<2:05:22, 88.50s/it]
#
#
#
# Generating walks (CPU: 1):  33%|███▎      | 41/125 [58:32<2:04:59, 89.29s/it]
#
#
# Generating walks (CPU: 1):  34%|███▎      | 42/125 [59:56<2:01:16, 87.66s/it]
#
#
# Generating walks (CPU: 1):  34%|███▍      | 43/125 [1:01:23<1:59:43, 87.61s/it]
#
#
# Generating walks (CPU: 1):  35%|███▌      | 44/125 [1:02:50<1:57:53, 87.33s/it]
#
#
# Generating walks (CPU: 1):  36%|███▌      | 45/125 [1:04:33<2:02:43, 92.04s/it]
#
#
#
#
# Generating walks (CPU: 1):  37%|███▋      | 46/125 [1:05:59<1:58:43, 90.18s/it]
#
#
# Generating walks (CPU: 1):  38%|███▊      | 47/125 [1:07:26<1:55:59, 89.22s/it]
#
#
# Generating walks (CPU: 1):  38%|███▊      | 48/125 [1:08:57<1:55:02, 89.64s/it]
#
#
# Generating walks (CPU: 1):  39%|███▉      | 49/125 [1:10:20<1:51:19, 87.89s/it]
#
#
# Generating walks (CPU: 1):  40%|████      | 50/125 [1:11:51<1:51:04, 88.85s/it]
#
#
# Generating walks (CPU: 1):  41%|████      | 51/125 [1:13:16<1:48:02, 87.60s/it]
#
#
# Generating walks (CPU: 1):  42%|████▏     | 52/125 [1:14:40<1:45:13, 86.49s/it]
#
#
# Generating walks (CPU: 1):  42%|████▏     | 53/125 [1:16:07<1:43:56, 86.62s/it]
#
#
# Generating walks (CPU: 1):  43%|████▎     | 54/125 [1:17:31<1:41:44, 85.98s/it]
#
#
#
# Generating walks (CPU: 1):  44%|████▍     | 55/125 [1:19:03<1:42:10, 87.58s/it]
#
#
# Generating walks (CPU: 1):  45%|████▍     | 56/125 [1:20:29<1:40:06, 87.05s/it]
#
#
#
#
# Generating walks (CPU: 1):  46%|████▌     | 57/125 [1:21:56<1:38:51, 87.23s/it]
#
#
# Generating walks (CPU: 1):  46%|████▋     | 58/125 [1:23:25<1:37:47, 87.58s/it]
#
#
# Generating walks (CPU: 1):  47%|████▋     | 59/125 [1:24:56<1:37:43, 88.84s/it]
#
#
# Generating walks (CPU: 1):  48%|████▊     | 60/125 [1:26:28<1:37:15, 89.78s/it]
#
#
# Generating walks (CPU: 1):  49%|████▉     | 61/125 [1:27:55<1:34:43, 88.81s/it]
#
#
# Generating walks (CPU: 1):  50%|████▉     | 62/125 [1:29:20<1:32:10, 87.79s/it]
#
#
# Generating walks (CPU: 1):  50%|█████     | 63/125 [1:30:50<1:31:15, 88.31s/it]
#
#
# Generating walks (CPU: 1):  51%|█████     | 64/125 [1:32:18<1:29:44, 88.27s/it]
#
#
#
#
#
# Generating walks (CPU: 1):  52%|█████▏    | 65/125 [1:33:43<1:27:04, 87.07s/it]
#
#
# Generating walks (CPU: 1):  53%|█████▎    | 66/125 [1:35:18<1:28:06, 89.60s/it]
#
#
# Generating walks (CPU: 1):  54%|█████▎    | 67/125 [1:36:47<1:26:28, 89.45s/it]
#
#
# Generating walks (CPU: 1):  54%|█████▍    | 68/125 [1:38:15<1:24:39, 89.12s/it]
#
#
# Generating walks (CPU: 1):  55%|█████▌    | 69/125 [1:39:38<1:21:22, 87.18s/it]
#
#
# Generating walks (CPU: 1):  56%|█████▌    | 70/125 [1:41:08<1:20:38, 87.98s/it]
#
#
# Generating walks (CPU: 1):  57%|█████▋    | 71/125 [1:42:34<1:18:47, 87.55s/it]
#
#
# Generating walks (CPU: 1):  58%|█████▊    | 72/125 [1:44:02<1:17:27, 87.69s/it]
#
#
# Generating walks (CPU: 1):  58%|█████▊    | 73/125 [1:45:25<1:14:35, 86.06s/it]
#
#
#
#
# Generating walks (CPU: 1):  59%|█████▉    | 74/125 [1:46:50<1:13:01, 85.92s/it]
#
#
# Generating walks (CPU: 1):  60%|██████    | 75/125 [1:48:15<1:11:25, 85.71s/it]
#
#
# Generating walks (CPU: 1):  61%|██████    | 76/125 [1:49:37<1:08:58, 84.47s/it]
#
#
# Generating walks (CPU: 1):  62%|██████▏   | 77/125 [1:51:03<1:07:56, 84.93s/it]
#
#
# Generating walks (CPU: 1):  62%|██████▏   | 78/125 [1:52:31<1:07:12, 85.80s/it]
#
#
# Generating walks (CPU: 1):  63%|██████▎   | 79/125 [1:53:52<1:04:50, 84.57s/it]
#
#
# Generating walks (CPU: 1):  64%|██████▍   | 80/125 [1:55:18<1:03:39, 84.88s/it]
#
#
#
# Generating walks (CPU: 1):  65%|██████▍   | 81/125 [1:56:48<1:03:21, 86.39s/it]
#
#
# Generating walks (CPU: 1):  66%|██████▌   | 82/125 [1:58:12<1:01:24, 85.68s/it]
#
#
# Generating walks (CPU: 1):  66%|██████▋   | 83/125 [1:59:36<59:37, 85.19s/it]
#
#
# Generating walks (CPU: 1):  67%|██████▋   | 84/125 [2:01:04<58:48, 86.07s/it]
#
#
# Generating walks (CPU: 1):  68%|██████▊   | 85/125 [2:02:37<58:48, 88.21s/it]
#
#
#
#
# Generating walks (CPU: 1):  69%|██████▉   | 86/125 [2:04:17<59:34, 91.64s/it]
#
#
# Generating walks (CPU: 1):  70%|██████▉   | 87/125 [2:05:48<57:50, 91.33s/it]
#
#
# Generating walks (CPU: 1):  70%|███████   | 88/125 [2:07:14<55:20, 89.74s/it]
#
#
# Generating walks (CPU: 1):  71%|███████   | 89/125 [2:08:37<52:36, 87.69s/it]
#
#
# Generating walks (CPU: 1):  72%|███████▏  | 90/125 [2:10:00<50:25, 86.43s/it]
#
#
# Generating walks (CPU: 1):  73%|███████▎  | 91/125 [2:11:33<50:00, 88.26s/it]
#
#
# Generating walks (CPU: 1):  74%|███████▎  | 92/125 [2:12:59<48:17, 87.80s/it]
#
#
#
# Generating walks (CPU: 1):  74%|███████▍  | 93/125 [2:14:29<47:03, 88.24s/it]
#
#
# Generating walks (CPU: 1):  75%|███████▌  | 94/125 [2:15:55<45:17, 87.65s/it]
#
#
# Generating walks (CPU: 1):  76%|███████▌  | 95/125 [2:17:20<43:29, 86.97s/it]
#
#
#
#
# Generating walks (CPU: 1):  77%|███████▋  | 96/125 [2:18:53<42:53, 88.74s/it]
#
#
# Generating walks (CPU: 1):  78%|███████▊  | 97/125 [2:20:21<41:15, 88.41s/it]
#
#
# Generating walks (CPU: 1):  78%|███████▊  | 98/125 [2:21:49<39:43, 88.27s/it]
#
#
# Generating walks (CPU: 1):  79%|███████▉  | 99/125 [2:23:08<37:01, 85.46s/it]
#
#
# Generating walks (CPU: 1):  80%|████████  | 100/125 [2:24:33<35:35, 85.44s/it]
#
#
# Generating walks (CPU: 1):  81%|████████  | 101/125 [2:25:58<34:09, 85.42s/it]
#
#
# Generating walks (CPU: 1):  82%|████████▏ | 102/125 [2:27:24<32:44, 85.43s/it]
#
#
# Generating walks (CPU: 1):  82%|████████▏ | 103/125 [2:28:49<31:18, 85.37s/it]
#
#
# Generating walks (CPU: 1):  83%|████████▎ | 104/125 [2:30:17<30:06, 86.01s/it]
#
#
#
#
# Generating walks (CPU: 1):  84%|████████▍ | 105/125 [2:31:46<29:02, 87.12s/it]
#
#
#
# Generating walks (CPU: 1):  85%|████████▍ | 106/125 [2:33:17<27:57, 88.28s/it]
#
#
# Generating walks (CPU: 1):  86%|████████▌ | 107/125 [2:34:47<26:37, 88.74s/it]
#
#
# Generating walks (CPU: 1):  86%|████████▋ | 108/125 [2:36:17<25:15, 89.17s/it]
#
#
# Generating walks (CPU: 1):  87%|████████▋ | 109/125 [2:37:44<23:33, 88.33s/it]
#
#
# Generating walks (CPU: 1):  88%|████████▊ | 110/125 [2:39:14<22:15, 89.04s/it]
#
#
# Generating walks (CPU: 1):  89%|████████▉ | 111/125 [2:40:42<20:39, 88.57s/it]
#
#
# Generating walks (CPU: 1):  90%|████████▉ | 112/125 [2:42:07<18:56, 87.45s/it]
#
#
# Generating walks (CPU: 1):  90%|█████████ | 113/125 [2:43:34<17:28, 87.36s/it]
#
#
# Generating walks (CPU: 4): 100%|██████████| 125/125 [2:44:54<00:00, 79.16s/it]
# Generating walks (CPU: 1):  91%|█████████ | 114/125 [2:45:02<16:05, 87.75s/it]
# Generating walks (CPU: 1):  92%|█████████▏| 115/125 [2:46:03<13:17, 79.73s/it]
# Generating walks (CPU: 1):  93%|█████████▎| 116/125 [2:47:08<11:15, 75.09s/it]
# Generating walks (CPU: 3): 100%|██████████| 125/125 [2:48:08<00:00, 80.71s/it]
# Generating walks (CPU: 2): 100%|██████████| 125/125 [2:54:14<00:00, 83.63s/it]
# Generating walks (CPU: 1): 100%|██████████| 125/125 [2:54:16<00:00, 83.65s/it]

# %%
# show the keys of the node2vec models. Which should be the list of models named by the repsective parameters
# the key would be used to collate the respective datasets, model evaluation results in the later processes
node2vec_models.keys()

# %%
# store the fitted node2vec model files in case it may be of use

filename = 'node2vec_models.pickle'
file_path = os.path.join(embeddings_path, filename)

with open(file_path, 'wb') as f:
    pickle.dump(node2vec_models, f, pickle.HIGHEST_PROTOCOL)

# %%
# load the genetic association list for use of positive labelling
positive_label_file_path = os.path.join('data', 'others', 'dise_asso_score_TH.csv')
ra_gene_ass_TH = pd.read_csv(positive_label_file_path)
positive_ids = ra_gene_ass_TH['target_id'].values.tolist()
print ("number of positive labels: ", len(positive_ids))
# Out:
# number of positive labels:  403

# %% [markdown]
# #### Create Dataset in .csv Format

# %%
# convert all embeddings files to dataframe and do the positive labelling
# export the datasets in csv format

# List all files in the directory
file_list = os.listdir(embeddings_path)

# Filter files with .emb extension
emb_files = [file for file in file_list if file.endswith(".emb")] # user can add more criteria to filter the emb files

# Iterate through .emb files and export to csv 
for emb_file in emb_files:
    file_path = os.path.join(embeddings_path, emb_file)
    file_name_without_ext = os.path.splitext(emb_file)[0]
    
    embed_df = load_embedding(file_path)
    dataset = positive_labelling(embed_df, positive_ids)
    dataset_filename = 'dataset_' + file_name_without_ext + '.csv'
    dataset_file_path = os.path.join(datasets_path, dataset_filename)
    dataset.to_csv(dataset_file_path, index=False)
